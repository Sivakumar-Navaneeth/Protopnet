# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivakumar-Navaneeth/Protopnet/blob/main/protopnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: unzip a file and save the contents inside it in a seperate folder

import zipfile

# Specify the path to the zip file and the name of the folder to extract the files to
zip_path = '/content/drive/MyDrive/Protopnet/Explaining_Prototypes.zip'
extract_folder = 'extracted_files'

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract all files to the specified folder
    zip_ref.extractall(extract_folder)

# %%
# !ls
# Out:
# drive  extracted_files	sample_data

# %%
# prompt: go to directory extracted_files/Explaining_Prototypes/

import os

# Change the current working directory to the extracted_files/Explaining_Prototypes/ directory
os.chdir(os.path.join('extracted_files', 'Explaining_Prototypes'))

# Print the contents of the current directory to verify
# !ls
# Out:
# combine_models.ipynb   log.py				     receptive_field.py
# CUB_200_2011	       main.py				     resnet_features.py
# CUB_200_2011.tgz       model.py				     run_pruning.py
# datasets	       overview_explaining_prototypes_2.png  save.py
# densenet_features.py   poster.pdf			     settings.py
# find_nearest.py        preprocessing			     slides.pdf
# global_analysis.py     preprocess.py			     supp_this_looks_like_that.pdf
# helpers.py	       prototype_activation.py		     this_looks_like_that.pdf
# img_aug.py	       prune.py				     train_and_test.py
# LICENSE		       push.py				     vgg_features.py
# links_to_datasets.txt  README.md
# local_analysis.py      README.txt

# %%
# !python main.py
# Out:
# 0
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# training set size: 5994
# push set size: 5994
# test set size: 5794
# batch size: 80
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to ./pretrained_models/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:02<00:00, 202MB/s]
# start training
# epoch: 	0
# 	warm
# 	train
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# ...

# %%
# !python prototype_activation.py
# Out:
# mod values:  {'contrast': 0.45, 'saturation': 0.7, 'hue': 0.1, 'shape': '4_0.05', 'texture': 4, 'brightness': 0.8}
# class:  133.White_throated_Sparrow 1 / 200
# class:  054.Blue_Grosbeak 2 / 200
# class:  076.Dark_eyed_Junco 3 / 200
# class:  084.Red_legged_Kittiwake 4 / 200
# class:  164.Cerulean_Warbler 5 / 200
#                         weighted_delta
# prototype modification
# 0         brightness          0.023370
#           contrast           -0.001304
#           hue                 0.035301
#           saturation          0.011033
#           shape               0.140575
# ...                                ...
# 1999      contrast            0.161137
#           hue                -0.013783
#           saturation          0.116856
#           shape              -0.023789
#           texture             0.101558
#
# [12000 rows x 1 columns]
# Done with global scores. Now saving the local scores...
# DONE with training set. Now calculating for the test set...
# ...

# %%
# !zip -r /content/extracted_after_explanation.zip /content/extracted_files/Explaining_Prototypes
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img882.png (stored 0%)
#   adding: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img1559.png (stored 0%)
#   adding: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img-original1230.png (deflated 0%)
#   adding: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img321.png (deflated 0%)
#   adding: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img-original1182.png (deflated 0%)
#   adding: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img-original_with_self_act1097.png (deflated 0%)
# ...

# %%
# !zip -r /content/extracted_saved_models.zip /content/extracted_files/Explaining_Prototypes/saved_models
# Out:
# Streaming output truncated to the last 5000 lines.
# updating: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-self-act1006.npy (deflated 15%)
# updating: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img-receptive_field915.png (deflated 0%)
# updating: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img882.png (stored 0%)
# updating: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img1559.png (stored 0%)
# updating: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img-original1230.png (deflated 0%)
# updating: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img321.png (deflated 0%)
# updating: content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-20/prototype-img-original1182.png (deflated 0%)
# ...

# %%
from google.colab import files
files.download("/content/extracted_saved_models.zip")

# %%
# !cp /content/extracted_after_explanation.zip /content/drive/MyDrive/Protopnet

# %%
# !cp /content/extracted_saved_models.zip /content/drive/MyDrive/Protopnet

# %%
from google.colab import files
files.download("/content/extracted.zip")
