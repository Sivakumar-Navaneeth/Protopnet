# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivakumar-Navaneeth/Protopnet/blob/main/protopnet_200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: unzip a file and save the contents inside it in a seperate folder

import zipfile

# Specify the path to the zip file and the name of the folder to extract the files to
zip_path = '/content/drive/MyDrive/Protopnet/extracted_after_explanation.zip'
extract_folder = 'extracted_files'

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract all files to the specified folder
    zip_ref.extractall(extract_folder)

# %%
# prompt: go to directory extracted_files/Explaining_Prototypes/

import os

# Change the current working directory to the extracted_files/Explaining_Prototypes/ directory
os.chdir(os.path.join('extracted_files', 'content', 'extracted_files', 'Explaining_Prototypes'))

# Print the contents of the current directory to verify
# !ls
# Out:
# combine_models.ipynb   main.py				     README.txt
# CUB_200_2011	       model.py				     receptive_field.py
# CUB_200_2011.tgz       overview_explaining_prototypes_2.png  resnet_features.py
# densenet_features.py   poster.pdf			     run_pruning.py
# find_nearest.py        preprocessing			     saved_models
# global_analysis.py     preprocess.py			     save.py
# helpers.py	       pretrained_models		     settings.py
# img_aug.py	       prototype_activation.py		     slides.pdf
# LICENSE		       prune.py				     supp_this_looks_like_that.pdf
# links_to_datasets.txt  push.py				     this_looks_like_that.pdf
# local_analysis.py      __pycache__			     train_and_test.py
# log.py		       README.md			     vgg_features.py

# %%
# !cp /content/drive/MyDrive/Protopnet/200push0.2382.pth /content/extracted_files/content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/200push0.2382.pth

# %%
zip_path = '/content/drive/MyDrive/Protopnet/model1-200.zip'
extract_folder = 'model'

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract all files to the specified folder
    zip_ref.extractall(extract_folder)

# %%
# !cp -r /content/extracted_files/content/extracted_files/Explaining_Prototypes/model/kaggle/working/saved_models/vgg19/003/img/epoch-200 /content/extracted_files/content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-200

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/img/epoch-200/prototype-img-original0.png')
img2 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0001_796111.jpg')

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img)
plt.show()
plt.imshow(img2)
plt.show()
# cv2.imshow('image', img)

# %%
# !python local_analysis.py -modeldir "./saved_models/vgg19/003/" -model "200push0.2382.pth" -imgdir "./CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross" -img "Black_Footed_Albatross_0001_796111.jpg" -imgclass 0
# Out:
# load model from ./saved_models/vgg19/003/200push0.2382.pth
# model base architecture: vgg19
# experiment run: 003/
# Prototypes are chosen from 200 number of classes.
# Their class identities are: [  0   0   0 ... 199 199 199]
# All prototypes connect most strongly to their respective classes.
# 0 (2, 0)
# Predicted: 2
# Actual: 0
# image index 0 in batch
# Most activated 10 prototypes of this image:
# top 1 activated prototype for this image:
# prototype index: 22
# prototype class identity: 2
# activation value (similarity score): 5.776203155517578
# last layer connection with predicted class: 1.0695233345031738
# most highly activated patch of the chosen image by this prototype:
# most highly activated patch by this prototype shown in the original image:
# prototype activation map of the chosen image:
# --------------------------------------------------------------
# top 2 activated prototype for this image:
# prototype index: 1276
# prototype class identity: 127
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/vgg19/003/200push0.2382.pth/most_activated_prototypes/most_highly_activated_patch_by_top-1_prototype.png')
img2 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/vgg19/003/200push0.2382.pth/most_activated_prototypes/most_highly_activated_patch_in_original_img_by_top-1_prototype.png')
img3 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/vgg19/003/200push0.2382.pth/most_activated_prototypes/prototype_activation_map_by_top-1_prototype.png')
img4 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/vgg19/003/200push0.2382.pth/most_activated_prototypes/top-1_activated_prototype.png')
img5 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/vgg19/003/200push0.2382.pth/most_activated_prototypes/top-1_activated_prototype_self_act.png')
img6 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/vgg19/003/200push0.2382.pth/most_activated_prototypes/top-1_activated_prototype_in_original_pimg.png')

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2RGB)
img5 = cv2.cvtColor(img5, cv2.COLOR_BGR2RGB)
img6 = cv2.cvtColor(img6, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img)
plt.show()
plt.imshow(img2)
plt.show()
plt.imshow(img3)
plt.show()
plt.imshow(img4)
plt.show()
plt.imshow(img6)
plt.show()
plt.imshow(img5)
plt.show()
# cv2.imshow('image', img)

# %%
img01 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/vgg19/003/200push0.2382.pth/top-18_class_prototypes/most_highly_activated_patch_by_top-10_prototype.png')
img02 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/vgg19/003/200push0.2382.pth/top-18_class_prototypes/most_highly_activated_patch_in_original_img_by_top-10_prototype.png')
img03 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/CUB_200_2011/CUB_200_2011/images/001.Black_footed_Albatross/vgg19/003/200push0.2382.pth/top-18_class_prototypes/prototype_activation_map_by_top-10_prototype.png')

img01 = cv2.cvtColor(img01, cv2.COLOR_BGR2RGB)
img02 = cv2.cvtColor(img02, cv2.COLOR_BGR2RGB)
img03 = cv2.cvtColor(img03, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img01)
plt.show()
plt.imshow(img02)
plt.show()
plt.imshow(img03)
plt.show()

# %%
# !python global_analysis.py -modeldir "./saved_models/vgg19/003/" -model "200push0.2382.pth"
# Out:
# load model from ./saved_models/vgg19/003/200push0.2382.pth
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# find nearest patches
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# batch 0
# batch 1
# batch 2
# batch 3
# batch 4
# batch 5
# batch 6
# batch 7
# batch 8
# batch 9
# batch 10
# batch 11
# batch 12
# batch 13
# batch 14
# batch 15
# batch 16
# batch 17
# batch 18
# ...

# %%
img01 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/200push0.2382_nearest_train/1190/prototype_in_original_pimg.png')
img02 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/200push0.2382_nearest_train/1026/prototype_in_original_pimg.png')
img03 = cv2.imread('/content/extracted_files/content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/200push0.2382_nearest_train/1/prototype_in_original_pimg.png')

img01 = cv2.cvtColor(img01, cv2.COLOR_BGR2RGB)
img02 = cv2.cvtColor(img02, cv2.COLOR_BGR2RGB)
img03 = cv2.cvtColor(img03, cv2.COLOR_BGR2RGB)

# Display the image
plt.title('Global Prototypes 1, 1026, 1190')
plt.imshow(img01)
plt.show()
plt.imshow(img02)
plt.show()
plt.imshow(img03)
plt.show()

# %%
# !python prototype_activation.py -modeldir "./saved_models/vgg19/003/" -model "200push0.2382.pth"
# Out:
# mod values:  {'contrast': 0.45, 'saturation': 0.7, 'hue': 0.1, 'shape': '4_0.05', 'texture': 4, 'brightness': 0.8}
# class:  001.Black_footed_Albatross 1 / 200
# class:  002.Laysan_Albatross 2 / 200
#                         weighted_delta
# prototype modification
# 0         brightness          0.515681
#           contrast            1.157926
#           hue                 1.395023
#           saturation          0.546932
#           shape               1.535790
# ...                                ...
# 1999      contrast            0.004567
#           hue                -0.006101
#           saturation          0.001108
#           shape               0.005402
#           texture             0.001954
#
# [12000 rows x 1 columns]
# Done with global scores. Now saving the local scores...
# DONE with training set. Now calculating for the test set...
# class:  098.Scott_Oriole 1 / 200
# class:  055.Evening_Grosbeak 2 / 200
# class:  111.Loggerhead_Shrike 3 / 200
# ...

# %%
import csv

local = '/content/extracted_files/content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/trainingset_local_prototype_scores_0.45_0.7_0.1_4_0.05_4_0.8.csv'
with open(local, 'r') as f:
  reader = csv.reader(f)
  for row in reader:
    print(row)
    if reader.line_num == 12:
      break
# Out:
# ['image', 'prototype', 'modification', 'delta', 'orig_similarity']
# ['Black_Footed_Albatross_0080_796096.JPEG', '0', 'contrast', '0.29837638', '1.0760176']
# ['Black_Footed_Albatross_0080_796096.JPEG', '1', 'contrast', '-0.30311096', '1.4983042']
# ['Black_Footed_Albatross_0080_796096.JPEG', '2', 'contrast', '0.043034554', '1.2796767']
# ['Black_Footed_Albatross_0080_796096.JPEG', '3', 'contrast', '-0.42943144', '4.522545']
# ['Black_Footed_Albatross_0080_796096.JPEG', '4', 'contrast', '0.46465373', '2.673809']
# ['Black_Footed_Albatross_0080_796096.JPEG', '5', 'contrast', '0.04555607', '3.413072']
# ['Black_Footed_Albatross_0080_796096.JPEG', '6', 'contrast', '0.9715431', '2.1595118']
# ['Black_Footed_Albatross_0080_796096.JPEG', '7', 'contrast', '0.47633827', '1.9011528']
# ['Black_Footed_Albatross_0080_796096.JPEG', '8', 'contrast', '-1.2757528', '2.066423']
# ['Black_Footed_Albatross_0080_796096.JPEG', '9', 'contrast', '2.1016173', '6.1239986']
# ...

# %%
globa = '/content/extracted_files/content/extracted_files/Explaining_Prototypes/saved_models/vgg19/003/trainingset_weighted_global_prototype_scores_0.45_0.7_0.1_4_0.05_4_0.8.csv'
with open(globa, 'r') as f:
  reader = csv.reader(f)
  for row in reader:
    print(row)
    if reader.line_num == 13:
      break
# Out:
# ['prototype', 'modification', 'weighted_delta']
# ['0', 'brightness', '0.515681']
# ['0', 'contrast', '1.1579261']
# ['0', 'hue', '1.3950225']
# ['0', 'saturation', '0.546932']
# ['0', 'shape', '1.5357904']
# ['0', 'texture', '1.0361856']
# ['1', 'brightness', '0.661935']
# ['1', 'contrast', '0.9309239']
# ['1', 'hue', '1.3030101']
# ['1', 'saturation', '0.60729206']
# ['1', 'shape', '1.5228451']
# ['1', 'texture', '0.7759249']
